# %% [markdown]
# <a href="https://colab.research.google.com/github/manyamanikandan447/coding-challenges/blob/main/module_1_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find prime numbers between 1 and n
n = int(input("Enter a number: "))

print("Prime numbers between 1 and", n, "are:")

for num in range(2, n+1):  # start from 2 (smallest prime)
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num, end=" ")

# %%
# Check if two strings are anagrams
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
if sorted(str1.lower()) == sorted(str2.lower()):
    print("The strings are anagrams.")
else:
    print("The strings are not anagrams.")
